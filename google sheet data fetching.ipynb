# %%
from df2gspread import gspread2df as g2d

# %%
import gspread

# %%
import pandas as pd

# %%
from oauth2client.service_account import ServiceAccountCredentials

# %%
scope = ['https://www.googleapis.com/auth/drive']

# %%
credentials = ServiceAccountCredentials.from_json_keyfile_name('Desktop/Login-4398ac0aa1d7.json', scope)

# %%
client = gspread.authorize(credentials)

# %%
sheet = client.open('google_sheet')

# %%
data = sheet.get_worksheet(0)

# %%
data.get_all_records()
# Out:
# [{'Row ID': 20847,
#   'Order Priority': 'High',
#   'Discount': 0.01,
#   'Unit Price': 2.84,
#   'Shipping Cost': 0.93,
#   'Customer ID': 3,
#   'Customer Name': 'Bonnie Potter',
#   'Ship Mode': 'Express Air',
#   'Customer Segment': 'Corporate',
#   'Product Category': 'Office Supplies',
#   'Product Sub-Category': 'Pens & Art Supplies',
#   'Product Container': 'Wrap Bag',
#   'Product Name': 'SANFORD Liquid Accent™ Tank-Style Highlighters',
#   'Product Base Margin': 0.54,
#   'Country': 'United States',
#   'Region': 'West',
#   'State or Province': 'Washington',
#   'City': 'Anacortes',
#   'Postal Code': 98221,
#   'Order Date': '2015-01-07 00:00:00',
#   'Ship Date': '2015-01-08 00:00:00',
#   'Profit': 4.56,
#   'Quantity ordered new': 4,
#   'Sales': 13.01,
#   'Order ID': 88522,
#   '': 0},
#  {'Row ID': 20228,
#   'Order Priority': 'Not Specified',
#   'Discount': 0.02,
#   'Unit Price': 500.98,
#   'Shipping Cost': 26.0,
#   'Customer ID': 5,
# ...

# %%
data1 = pd.DataFrame(data.get_all_records())

# %%
data1
# Out:
#                     City        Country  Customer ID  \
# 0     0        Anacortes  United States            3
# 1            San Gabriel  United States            5
# 2                Roselle  United States           11
# 3             Prior Lake  United States           14
# 4             Prior Lake  United States           14
# 5             Prior Lake  United States           14
# 6             Prior Lake  United States           14
# 7              Smithtown  United States           15
# 8              Smithtown  United States           15
# 9               Syracuse  United States           16
# 10              Syracuse  United States           16
# 11                Helena  United States           18
# 12              Missoula  United States           19
# 13         New York City  United States           21
# 14         New York City  United States           21
# 15         New York City  United States           21
# 16         Laguna Niguel  United States           24
# ...

# %%
spreadsheet = '1pkLRWSXivHrNWQDBvBHBLtljCOtM03D3fjrYe-bVATg'

# %%
wks_name = 'New Sheet'

# %%
df = g2d.download(spreadsheet, wks_name, col_names = True, row_names = True)
# Out:
# //anaconda3/lib/python3.7/site-packages/oauth2client/_helpers.py:255: UserWarning: Cannot access /Users/ullassood/.oauth/drive.json: No such file or directory
#   warnings.warn(_MISSING_FILE_MESSAGE.format(filename))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/oauth2client/clientsecrets.py in _loadfile(filename)
#     120     try:
# --> 121         with open(filename, 'r') as fp:
#     122             obj = json.load(fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ullassood/.gdrive_private'
#
# During handling of the above exception, another exception occurred:
#
# InvalidClientSecretsError                 Traceback (most recent call last)
# <ipython-input-15-49e36a28129a> in <module>
# ----> 1 df = g2d.download(spreadsheet, wks_name, col_names = True, row_names = True)
#
# ...
